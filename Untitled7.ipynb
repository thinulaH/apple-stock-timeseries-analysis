# %% [markdown]
# <a href="https://colab.research.google.com/github/thinulaH/apple-stock-timeseries-analysis/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import yfinance as yf

df = yf.download("AAPL", start="2010-01-01")
data = yf.download("AAPL", start = "2020-01-01")
print(df.head())
# Out:
# /tmp/ipykernel_42195/627516955.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL", start="2010-01-01")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_42195/627516955.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL")
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.412381  6.427063  6.363542  6.395003  493729600
# 2010-01-05  6.423470  6.459725  6.389611  6.430062  601904800
# 2010-01-06  6.321295  6.448937  6.314703  6.423469  552160000
# 2010-01-07  6.309611  6.352159  6.263768  6.344668  477131200
# 2010-01-08  6.351558  6.352158  6.264067  6.301220  447610800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4091 entries, 2010-01-04 to 2026-04-09
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   4091 non-null   float64
#  1   (High, AAPL)    4091 non-null   float64
#  2   (Low, AAPL)     4091 non-null   float64
#  3   (Open, AAPL)    4091 non-null   float64
#  4   (Volume, AAPL)  4091 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 191.8 KB

# %%
df.head()
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.412381  6.427063  6.363542  6.395003  493729600
# 2010-01-05  6.423470  6.459725  6.389611  6.430062  601904800
# 2010-01-06  6.321295  6.448937  6.314703  6.423469  552160000
# 2010-01-07  6.309611  6.352159  6.263768  6.344668  477131200
# 2010-01-08  6.351558  6.352158  6.264067  6.301220  447610800

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df.loc["2022-03"]
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2022-03-01  159.900833  163.232110  158.695702  161.370510   83474400
# 2022-03-02  163.192917  163.976748  159.655894  161.066786   79724800
# 2022-03-03  162.869553  165.495383  162.203306  165.064275   76678400
# 2022-03-04  159.871460  162.203352  158.823098  161.164783   83737200
# 2022-03-07  156.079651  161.684019  155.824897  160.057573   96418800
# 2022-03-08  154.257278  159.587309  152.650432  155.609386  131148300
# 2022-03-09  159.655869  160.106576  156.187438  158.215584   91454900
# 2022-03-10  155.315430  157.147622  152.826769  156.961460  105342000
# 2022-03-11  151.602081  156.060105  151.376735  155.717174   96970100
# 2022-03-14  147.575180  151.004427  147.065703  148.388403  108732100
# 2022-03-15  151.954788  152.425096  147.340011  147.849488   92964300
# ...

# %%
df.loc["2020-03"].Close.mean()
# Out:
# Ticker
# AAPL    63.413295
# dtype: float64

# %%
df.Close.resample('M').mean().plot()
# Out:
# /tmp/ipykernel_42195/4123725665.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.Close.resample('M').mean().plot()
# <Axes: xlabel='Date'>

# %%
df.Close.resample('Y').mean().plot()
# Out:
# /tmp/ipykernel_42195/2788181658.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.Close.resample('Y').mean().plot()
# <Axes: xlabel='Date'>

# %%
df.Close.resample('Y').mean().plot(kind='bar')
# Out:
# /tmp/ipykernel_42195/2688626245.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.Close.resample('Y').mean().plot(kind='bar')
# <Axes: xlabel='Date'>

# %%
import yfinance as yf

data = yf.download("AAPL", start="2010-01-01")
print(data.head())
# Out:
# /tmp/ipykernel_42195/3308096063.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2010-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.412383  6.427064  6.363543  6.395004  493729600
# 2010-01-05  6.423470  6.459726  6.389612  6.430063  601904800
# 2010-01-06  6.321296  6.448939  6.314704  6.423470  552160000
# 2010-01-07  6.309608  6.352156  6.263765  6.344666  477131200
# 2010-01-08  6.351559  6.352159  6.264068  6.301221  447610800

# %%
data.index
# Out:
# DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2026-03-26', '2026-03-27', '2026-03-30', '2026-03-31',
#                '2026-04-01', '2026-04-02', '2026-04-06', '2026-04-07',
#                '2026-04-08', '2026-04-09'],
#               dtype='datetime64[ns]', name='Date', length=4091, freq=None)

# %%
data.parse_dates=['Date']
# Out:
# /tmp/ipykernel_42195/2911833032.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.parse_dates=['Date']

# %%
type(data.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
data.Close.resample('M').mean().plot()
# Out:
# /tmp/ipykernel_42195/3007905159.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data.Close.resample('M').mean().plot()
# <Axes: xlabel='Date'>

# %%
data.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.asfreq('D', method='Pad')
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2010-01-04    6.412383    6.427064    6.363543    6.395004  493729600
# 2010-01-05    6.423470    6.459726    6.389612    6.430063  601904800
# 2010-01-06    6.321296    6.448939    6.314704    6.423470  552160000
# 2010-01-07    6.309608    6.352156    6.263765    6.344666  477131200
# 2010-01-08    6.351559    6.352159    6.264068    6.301221  447610800
# ...                ...         ...         ...         ...        ...
# 2026-04-05  255.919998  256.130005  250.649994  254.199997   31289400
# 2026-04-06  258.859985  262.160004  256.459991  256.510010   29329900
# 2026-04-07  253.500000  256.200012  245.699997  256.160004   62148000
# 2026-04-08  258.899994  259.750000  256.529999  258.450012   41008200
# 2026-04-09  259.915009  260.529999  256.070007  259.369995   14145773
#
# [5940 rows x 5 columns]

# %%
import numpy as np

# %%
random = np.random.randint(1, 101, 10)
